# %%
import pandas as pd

# %%
train_df = pd.read_parquet('../data/processed/train.parquet')

# %%
train_df["deposit"]
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 22785     True
# 22786     True
# 22787     True
# 22788     True
# 22789     True
# Name: deposit, Length: 22790, dtype: bool

# %%
[
            "latitude", "longitude", "distance_to_center", "angle_from_center",
            "distance_to_station1", "distance_to_station2", "distance_to_station3",
            "bedrooms", "bathrooms", "deposit", "zone", "borough",
            "propertyType", "furnishType", "NoiseClass", "letType",
            "TFL1", "TFL2", "TFL3", "RAIL1", "RAIL2", "RAIL3",
        ]

# %%
train_df = train_df.drop(columns=['zone'])

# %%
train_df.to_parquet('../data/processed/train.parquet')

# %%
test_df = pd.read_parquet('../data/processed/test.parquet')

# %%
test_df = test_df.drop(columns=['zone'])

# %%
test_df.to_parquet('../data/processed/test.parquet')
